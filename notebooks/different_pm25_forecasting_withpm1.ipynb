# %%
print("hello")
# Out:
# hello

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.ensemble import (
    RandomForestRegressor,
    GradientBoostingRegressor,
    ExtraTreesRegressor,
)
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score,
)

# %% [markdown]
# Import data

# %%
df= pd.read_csv("../data/processed/ratnapark/ratnapark_pm1_pm25_pm10_daily.csv")
df["date"]=pd.to_datetime(df["date"])
df=(df.sort_values("date").reset_index(drop=True))
print("shape:", df.shape)
display(df.head())
# Out:
# shape: (1887, 4)
#         date         pm1       pm2_5        pm10
# 0 2016-08-25  144.026083  187.599837  269.346300
# 1 2016-08-27  121.881565  159.537520  230.975440
# 2 2016-08-28   98.196718  124.696523  171.362190
# 3 2016-08-29   54.083770   63.915300   78.042140
# 4 2016-09-07  127.947061  168.501950  245.585955

# %% [markdown]
# Create 7 days lag

# %%
for lag in range(1, 8):
    df[f"pm2_5_lag_{lag}"] = df["pm2_5"].shift(lag)
    df[f"pm10_lag_{lag}"] = df["pm10"].shift(lag)
    df[f"pm1_lag_{lag}"]= df["pm1"].shift(lag)

# %% [markdown]
# Create forecasting target

# %%
df["target_pm2_5"] = df["pm2_5"].shift(-1)

# %% [markdown]
# Remove unusable rows

# %%
df_model= df.dropna().copy()
print("original rows:", len(df))
print("usable rows:", len(df_model))

display(df_model.head())
# Out:
# original rows: 1887
# usable rows: 1879
#          date         pm1       pm2_5        pm10  pm2_5_lag_1  pm10_lag_1  \
# 7  2016-09-12  105.117225  132.785217  182.608250    29.042917   32.999425
# 8  2016-09-18   92.885558  119.215280  166.891925   132.785217  182.608250
# 9  2016-09-19   76.851917   96.302953  130.395945   119.215280  166.891925
# 10 2016-09-20   80.535347  104.368733  147.140180    96.302953  130.395945
# 11 2016-09-21   83.568385  106.495640  145.790225   104.368733  147.140180
#
#      pm1_lag_1  pm2_5_lag_2  pm10_lag_2   pm1_lag_2  ...  pm2_5_lag_5  \
# 7    26.360702    63.253007   83.520250   51.507960  ...   124.696523
# 8   105.117225    29.042917   32.999425   26.360702  ...    63.915300
# 9    92.885558   132.785217  182.608250  105.117225  ...   168.501950
# 10   76.851917   119.215280  166.891925   92.885558  ...    63.253007
# 11   80.535347    96.302953  130.395945   76.851917  ...    29.042917
#
#     pm10_lag_5   pm1_lag_5  pm2_5_lag_6  pm10_lag_6   pm1_lag_6  pm2_5_lag_7  \
# 7   171.362190   98.196718   159.537520  230.975440  121.881565   187.599837
# 8    78.042140   54.083770   124.696523  171.362190   98.196718   159.537520
# 9   245.585955  127.947061    63.915300   78.042140   54.083770   124.696523
# 10   83.520250   51.507960   168.501950  245.585955  127.947061    63.915300
# 11   32.999425   26.360702    63.253007   83.520250   51.507960   168.501950
#
#     pm10_lag_7   pm1_lag_7  target_pm2_5
# 7   269.346300  144.026083    119.215280
# 8   230.975440  121.881565     96.302953
# 9   171.362190   98.196718    104.368733
# 10   78.042140   54.083770    106.495640
# 11  245.585955  127.947061    103.276103
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Rolling Stats

# %% [markdown]
# Import data and sorting

# %%
rolling_df = pd.read_csv("../data/processed/ratnapark/ratnapark_pm1_pm25_pm10_daily.csv")

rolling_df["date"] = pd.to_datetime(
    rolling_df["date"]
)

rolling_df = (
    rolling_df.sort_values("date").reset_index(drop=True))

display(rolling_df.head())
# Out:
#         date         pm1       pm2_5        pm10
# 0 2016-08-25  144.026083  187.599837  269.346300
# 1 2016-08-27  121.881565  159.537520  230.975440
# 2 2016-08-28   98.196718  124.696523  171.362190
# 3 2016-08-29   54.083770   63.915300   78.042140
# 4 2016-09-07  127.947061  168.501950  245.585955

# %% [markdown]
# Create target

# %%
rolling_df["target_pm2_5"]= (rolling_df["pm2_5"]).shift(-1)

# %% [markdown]
# Create rolling features with 3 days and 7 days mean and std

# %%
for pollutant in ["pm2_5", "pm10","pm1"]:

    rolling_df[f"{pollutant}_rolling_mean_3"] = (
        rolling_df[pollutant]
        .shift(1)
        .rolling(window=3)
        .mean()
    )

    rolling_df[f"{pollutant}_rolling_mean_7"] = (
        rolling_df[pollutant]
        .shift(1)
        .rolling(window=7)
        .mean()
    )

    rolling_df[f"{pollutant}_rolling_std_3"] = (
        rolling_df[pollutant]
        .shift(1)
        .rolling(window=3)
        .std()
    )

    rolling_df[f"{pollutant}_rolling_std_7"] = (
        rolling_df[pollutant]
        .shift(1)
        .rolling(window=7)
        .std()
    )

# %% [markdown]
# adding minn and max too

# %%
for pollutant in ["pm2_5", "pm10","pm1"]:

    rolling_df[f"{pollutant}_rolling_min_3"] = (
        rolling_df[pollutant]
        .shift(1)
        .rolling(window=3)
        .min()
    )

    rolling_df[f"{pollutant}_rolling_min_7"] = (
        rolling_df[pollutant]
        .shift(1)
        .rolling(window=7)
        .min()
    )

    rolling_df[f"{pollutant}_rolling_max_3"] = (
        rolling_df[pollutant]
        .shift(1)
        .rolling(window=3)
        .max()
    )

    rolling_df[f"{pollutant}_rolling_max_7"] = (
        rolling_df[pollutant]
        .shift(1)
        .rolling(window=7)
        .max()
    )

# %%
print("Shape:", rolling_df.shape)

display(
    rolling_df[
        [
            "date",
            "pm2_5",
            "pm10",
            "pm1",
            "pm2_5_rolling_mean_3",
            "pm2_5_rolling_mean_7",
            "pm10_rolling_mean_3",
            "pm10_rolling_mean_7",
            "pm1_rolling_mean_3",
            "pm1_rolling_mean_7",
            "target_pm2_5",
        ]
    ].head(10)
)
# Out:
# Shape: (1887, 29)
#         date       pm2_5        pm10         pm1  pm2_5_rolling_mean_3  \
# 0 2016-08-25  187.599837  269.346300  144.026083                   NaN
# 1 2016-08-27  159.537520  230.975440  121.881565                   NaN
# 2 2016-08-28  124.696523  171.362190   98.196718                   NaN
# 3 2016-08-29   63.915300   78.042140   54.083770            157.277960
# 4 2016-09-07  168.501950  245.585955  127.947061            116.049781
# 5 2016-09-10   63.253007   83.520250   51.507960            119.037924
# 6 2016-09-11   29.042917   32.999425   26.360702             98.556752
# 7 2016-09-12  132.785217  182.608250  105.117225             86.932624
# 8 2016-09-18  119.215280  166.891925   92.885558             75.027047
# 9 2016-09-19   96.302953  130.395945   76.851917             93.681138
#
#    pm2_5_rolling_mean_7  pm10_rolling_mean_3  pm10_rolling_mean_7  \
# 0                   NaN                  NaN                  NaN
# 1                   NaN                  NaN                  NaN
# 2                   NaN                  NaN                  NaN
# 3                   NaN           223.894643                  NaN
# 4                   NaN           160.126590                  NaN
# 5                   NaN           164.996762                  NaN
# 6                   NaN           135.716115                  NaN
# 7            113.792436           120.701877           158.833100
# 8            105.961776            99.709308           146.441950
# 9            100.201456           127.499867           137.287162
#
#    pm1_rolling_mean_3  pm1_rolling_mean_7  target_pm2_5
# 0                 NaN                 NaN    159.537520
# 1                 NaN                 NaN    124.696523
# 2                 NaN                 NaN     63.915300
# 3          121.368122                 NaN    168.501950
# 4           91.387351                 NaN     63.253007
# 5           93.409183                 NaN     29.042917
# 6           77.846264                 NaN    132.785217
# 7           68.605241           89.143408    119.215280
# 8           60.995296           83.585000     96.302953
# 9           74.787828           79.442713    104.368733

# %% [markdown]
# Remove unusable rows

# %%
rolling_model_df = (
    rolling_df
    .dropna()
    .reset_index(drop=True)
)

print("Original rows:", len(rolling_df))
print("Usable rows:", len(rolling_model_df))
# Out:
# Original rows: 1887
# Usable rows: 1879

# %% [markdown]
# EWMA

# %% [markdown]
# Import data and sorting

# %%
ewma_df = pd.read_csv("../data/processed/ratnapark/ratnapark_pm1_pm25_pm10_daily.csv")

ewma_df["date"] = pd.to_datetime(
    ewma_df["date"]
)

ewma_df = (
    ewma_df.sort_values("date").reset_index(drop=True)
)

# %% [markdown]
# Create target

# %%
ewma_df["target_pm2_5"] = (ewma_df["pm2_5"].shift(-1))

# %% [markdown]
# Create features

# %%
for pollutant in ["pm2_5", "pm10","pm1"]:

    ewma_df[f"{pollutant}_ewma_3"] = (
        ewma_df[pollutant]
        .shift(1)
        .ewm(span=3, adjust=False)
        .mean()
    )

    ewma_df[f"{pollutant}_ewma_7"] = (
        ewma_df[pollutant]
        .shift(1)
        .ewm(span=7, adjust=False)
        .mean()
    )

# %%
display(
    ewma_df[
        [
            "date",
            "pm2_5",
            "pm10",
            "pm1",
            "pm2_5_ewma_3",
            "pm2_5_ewma_7",
            "pm10_ewma_3",
            "pm10_ewma_7",
            "pm1_ewma_3",
            "pm1_ewma_7",
            "target_pm2_5",
        ]
    ].head(10)
)
# Out:
#         date       pm2_5        pm10         pm1  pm2_5_ewma_3  pm2_5_ewma_7  \
# 0 2016-08-25  187.599837  269.346300  144.026083           NaN           NaN
# 1 2016-08-27  159.537520  230.975440  121.881565    187.599837    187.599837
# 2 2016-08-28  124.696523  171.362190   98.196718    173.568678    180.584258
# 3 2016-08-29   63.915300   78.042140   54.083770    149.132601    166.612324
# 4 2016-09-07  168.501950  245.585955  127.947061    106.523950    140.938068
# 5 2016-09-10   63.253007   83.520250   51.507960    137.512950    147.829038
# 6 2016-09-11   29.042917   32.999425   26.360702    100.382978    126.685031
# 7 2016-09-12  132.785217  182.608250  105.117225     64.712948    102.274502
# 8 2016-09-18  119.215280  166.891925   92.885558     98.749082    109.902181
# 9 2016-09-19   96.302953  130.395945   76.851917    108.982181    112.230456
#
#    pm10_ewma_3  pm10_ewma_7  pm1_ewma_3  pm1_ewma_7  target_pm2_5
# 0          NaN          NaN         NaN         NaN    159.537520
# 1   269.346300   269.346300  144.026083  144.026083    124.696523
# 2   250.160870   259.753585  132.953824  138.489953     63.915300
# 3   210.761530   237.655736  115.575271  128.416644    168.501950
# 4   144.401835   197.752337   84.829520  109.833426     63.253007
# 5   194.993895   209.710742  106.388291  114.361834     29.042917
# 6   139.257072   178.163119   78.948125   98.648366    132.785217
# 7    86.128249   141.872195   52.654414   80.576450    119.215280
# 8   134.368249   152.056209   78.885819   86.711644     96.302953
# 9   150.630087   155.765138   85.885688   88.255122    104.368733

# %% [markdown]
# Remove unusable rows

# %%
ewma_model_df = (
    ewma_df
    .dropna()
    .reset_index(drop=True)
)

print("Original rows:", len(ewma_df))
print("Usable rows:", len(ewma_model_df))
# Out:
# Original rows: 1887
# Usable rows: 1885

# %% [markdown]
# Change/Trend features

# %% [markdown]
# Load data and sorting

# %%
change_df = pd.read_csv("../data/processed/ratnapark/ratnapark_pm1_pm25_pm10_daily.csv")

change_df["date"] = pd.to_datetime(
    change_df["date"]
)

change_df = (
    change_df
    .sort_values("date")
    .reset_index(drop=True)
)

# %% [markdown]
# Create target

# %%
change_df["target_pm2_5"] = (
    change_df["pm2_5"].shift(-1)
)

# %% [markdown]
# Create change features

# %%
for pollutant in ["pm2_5", "pm10","pm1"]:

    change_df[f"{pollutant}_change_1"] = (
        change_df[pollutant]
        - change_df[pollutant].shift(1)
    )

    change_df[f"{pollutant}_change_3"] = (
        change_df[pollutant]
        - change_df[pollutant].shift(3)
    )

    change_df[f"{pollutant}_change_7"] = (
        change_df[pollutant]
        - change_df[pollutant].shift(7)
    )

# %% [markdown]
# Calculate change percentage too

# %%
for pollutant in ["pm2_5", "pm10","pm1"]:

    change_df[f"{pollutant}_pct_change_1"] = (
        change_df[pollutant]
        .pct_change(1)
    )

    change_df[f"{pollutant}_pct_change_3"] = (
        change_df[pollutant]
        .pct_change(3)
    )

    change_df[f"{pollutant}_pct_change_7"] = (
        change_df[pollutant]
        .pct_change(7)
    )

# %%
display(
    change_df[
        [
            "date",
            "pm2_5",
            "pm10",
            "pm1",
            "pm2_5_change_1",
            "pm2_5_change_3",
            "pm2_5_change_7",
            "pm2_5_pct_change_1",
            "pm2_5_pct_change_3",
            "pm2_5_pct_change_7",
            "pm10_change_1",
            "pm10_change_3",
            "pm10_change_7",
            "pm10_pct_change_1",
            "pm10_pct_change_3",
            "pm10_pct_change_7",
            "pm1_change_1",
            "pm1_change_3",
            "pm1_change_7",
            "pm1_pct_change_1",
            "pm1_pct_change_3",
            "pm1_pct_change_7",
            "target_pm2_5",
        ]
    ].head(10)
)
# Out:
#         date       pm2_5        pm10         pm1  pm2_5_change_1  \
# 0 2016-08-25  187.599837  269.346300  144.026083             NaN
# 1 2016-08-27  159.537520  230.975440  121.881565      -28.062317
# 2 2016-08-28  124.696523  171.362190   98.196718      -34.840997
# 3 2016-08-29   63.915300   78.042140   54.083770      -60.781223
# 4 2016-09-07  168.501950  245.585955  127.947061      104.586650
# 5 2016-09-10   63.253007   83.520250   51.507960     -105.248943
# 6 2016-09-11   29.042917   32.999425   26.360702      -34.210090
# 7 2016-09-12  132.785217  182.608250  105.117225      103.742300
# 8 2016-09-18  119.215280  166.891925   92.885558      -13.569937
# 9 2016-09-19   96.302953  130.395945   76.851917      -22.912327
#
#    pm2_5_change_3  pm2_5_change_7  pm2_5_pct_change_1  pm2_5_pct_change_3  \
# 0             NaN             NaN                 NaN                 NaN
# 1             NaN             NaN           -0.149586                 NaN
# 2             NaN             NaN           -0.218387                 NaN
# 3     -123.684537             NaN           -0.487433           -0.659300
# 4        8.964430             NaN            1.636332            0.056190
# 5      -61.443517             NaN           -0.624616           -0.492744
# 6      -34.872383             NaN           -0.540845           -0.545603
# 7      -35.716733       -54.81462            3.572034           -0.211966
# 8       55.962273       -40.32224           -0.102195            0.884737
# 9       67.260037       -28.39357           -0.192193            2.315884
#
#    pm2_5_pct_change_7  ...  pm10_pct_change_1  pm10_pct_change_3  \
# 0                 NaN  ...                NaN                NaN
# 1                 NaN  ...          -0.142459                NaN
# 2                 NaN  ...          -0.258093                NaN
# 3                 NaN  ...          -0.544578          -0.710254
# 4                 NaN  ...           2.146838           0.063256
# 5                 NaN  ...          -0.659914          -0.512610
# 6                 NaN  ...          -0.604893          -0.577159
# 7           -0.292189  ...           4.533680          -0.256439
# 8           -0.252745  ...          -0.086066           0.998221
# 9           -0.227701  ...          -0.218680           2.951461
#
#    pm10_pct_change_7  pm1_change_1  pm1_change_3  pm1_change_7  \
# 0                NaN           NaN           NaN           NaN
# 1                NaN    -22.144518           NaN           NaN
# 2                NaN    -23.684847           NaN           NaN
# 3                NaN    -44.112948    -89.942312           NaN
# 4                NaN     73.863291      6.065496           NaN
# 5                NaN    -76.439101    -46.688758           NaN
# 6                NaN    -25.147257    -27.723068           NaN
# 7          -0.322032     78.756523    -22.829836    -38.908857
# 8          -0.277447    -12.231668     41.377598    -28.996007
# 9          -0.239062    -16.033640     50.491215    -21.344800
#
#    pm1_pct_change_1  pm1_pct_change_3  pm1_pct_change_7  target_pm2_5
# 0               NaN               NaN               NaN    159.537520
# 1         -0.153754               NaN               NaN    124.696523
# 2         -0.194327               NaN               NaN     63.915300
# 3         -0.449230         -0.624486               NaN    168.501950
# 4          1.365720          0.049765               NaN     63.253007
# 5         -0.597428         -0.475461               NaN     29.042917
# 6         -0.488221         -0.512595               NaN    132.785217
# 7          2.987649         -0.178432         -0.270151    119.215280
# 8         -0.116362          0.803324         -0.237903     96.302953
# 9         -0.172617          1.915397         -0.217368    104.368733
#
# [10 rows x 23 columns]

# %% [markdown]
# Remove unusable rows

# %%
change_model_df = (
    change_df
    .dropna()
    .reset_index(drop=True)
)

print("Original rows:", len(change_df))
print("Usable rows:", len(change_model_df))
# Out:
# Original rows: 1887
# Usable rows: 1879

# %% [markdown]
# Combined one : 7-day lags, rolling mean/std, EWMA, change/trend

# %%
combined_df = pd.read_csv("../data/processed/ratnapark/ratnapark_pm1_pm25_pm10_daily.csv")

combined_df["date"] = pd.to_datetime(
    combined_df["date"]
)

combined_df = (
    combined_df.sort_values("date").reset_index(drop=True)
)

print("Shape:", combined_df.shape)

display(combined_df.head())
# Out:
# Shape: (1887, 4)
#         date         pm1       pm2_5        pm10
# 0 2016-08-25  144.026083  187.599837  269.346300
# 1 2016-08-27  121.881565  159.537520  230.975440
# 2 2016-08-28   98.196718  124.696523  171.362190
# 3 2016-08-29   54.083770   63.915300   78.042140
# 4 2016-09-07  127.947061  168.501950  245.585955

# %% [markdown]
# Create target

# %%
combined_df["target_pm2_5"] = (
    combined_df["pm2_5"].shift(-1)
)

# %% [markdown]
# Add 7 days lags

# %%
for lag in range(1, 8):

    combined_df[f"pm2_5_lag_{lag}"] = (
        combined_df["pm2_5"].shift(lag)
    )

    combined_df[f"pm10_lag_{lag}"] = (
        combined_df["pm10"].shift(lag)
    )

# %% [markdown]
# Add rolling features

# %%
for pollutant in ["pm2_5", "pm10","pm1"]:

    combined_df[f"{pollutant}_rolling_mean_3"] = (
        combined_df[pollutant]
        .shift(1)
        .rolling(3)
        .mean()
    )

    combined_df[f"{pollutant}_rolling_mean_7"] = (
        combined_df[pollutant]
        .shift(1)
        .rolling(7)
        .mean()
    )

    combined_df[f"{pollutant}_rolling_std_7"] = (
        combined_df[pollutant]
        .shift(1)
        .rolling(7)
        .std()
    )

# %% [markdown]
# add ewma

# %%
for pollutant in ["pm2_5", "pm10","pm1"]:

    combined_df[f"{pollutant}_ewma_3"] = (
        combined_df[pollutant]
        .shift(1)
        .ewm(span=3, adjust=False)
        .mean()
    )

    combined_df[f"{pollutant}_ewma_7"] = (
        combined_df[pollutant]
        .shift(1)
        .ewm(span=7, adjust=False)
        .mean()
    )

# %% [markdown]
# Add change and trends

# %%
for pollutant in ["pm2_5", "pm10","pm1"]:

    combined_df[f"{pollutant}_ewma_3"] = (
        combined_df[pollutant]
        .shift(1)
        .ewm(span=3, adjust=False)
        .mean()
    )

    combined_df[f"{pollutant}_ewma_7"] = (
        combined_df[pollutant]
        .shift(1)
        .ewm(span=7, adjust=False)
        .mean()
    )

# %% [markdown]
# Feature counts

# %%
feature_columns = [
    col
    for col in combined_df.columns
    if col not in [
        "date",
        "pm2_5",
        "pm10",
        "pm1",
        "target_pm2_5",
    ]
]

print("Total features:", len(feature_columns))

print("\nFeatures:")
for feature in feature_columns:
    print(feature)
# Out:
# Total features: 29
#
# Features:
# pm2_5_lag_1
# pm10_lag_1
# pm2_5_lag_2
# pm10_lag_2
# pm2_5_lag_3
# pm10_lag_3
# pm2_5_lag_4
# pm10_lag_4
# pm2_5_lag_5
# pm10_lag_5
# pm2_5_lag_6
# pm10_lag_6
# pm2_5_lag_7
# pm10_lag_7
# pm2_5_rolling_mean_3
# pm2_5_rolling_mean_7
# pm2_5_rolling_std_7
# pm10_rolling_mean_3
# pm10_rolling_mean_7
# pm10_rolling_std_7
# pm1_rolling_mean_3
# pm1_rolling_mean_7
# pm1_rolling_std_7
# pm2_5_ewma_3
# pm2_5_ewma_7
# pm10_ewma_3
# pm10_ewma_7
# pm1_ewma_3
# pm1_ewma_7

# %% [markdown]
# Remove unusable rows

# %%
combined_model_df = (
    combined_df
    .dropna()
    .reset_index(drop=True)
)

print("Original rows:", len(combined_df))
print("Usable rows:", len(combined_model_df))
display(combined_model_df.head(10))
print("Features:", len(feature_columns))
# Out:
# Original rows: 1887
# Usable rows: 1879
#         date         pm1       pm2_5        pm10  target_pm2_5  pm2_5_lag_1  \
# 0 2016-09-12  105.117225  132.785217  182.608250    119.215280    29.042917
# 1 2016-09-18   92.885558  119.215280  166.891925     96.302953   132.785217
# 2 2016-09-19   76.851917   96.302953  130.395945    104.368733   119.215280
# 3 2016-09-20   80.535347  104.368733  147.140180    106.495640    96.302953
# 4 2016-09-21   83.568385  106.495640  145.790225    103.276103   104.368733
# 5 2016-09-22   82.765052  103.276103  137.984515     51.489237   106.495640
# 6 2016-09-23   44.094760   51.489237   62.204385     90.335197   103.276103
# 7 2016-09-24   72.552228   90.335197  118.025195    107.614070    51.489237
# 8 2016-09-25   84.983893  107.614070  146.479725     66.504697    90.335197
# 9 2016-09-26   53.756037   66.504697   89.382590     92.105213   107.614070
#
#    pm10_lag_1  pm2_5_lag_2  pm10_lag_2  pm2_5_lag_3  ...  pm10_rolling_std_7  \
# 0   32.999425    63.253007   83.520250   168.501950  ...           94.104586
# 1  182.608250    29.042917   32.999425    63.253007  ...           82.068412
# 2  166.891925   132.785217  182.608250    29.042917  ...           74.270861
# 3  130.395945   119.215280  166.891925   132.785217  ...           72.736509
# 4  147.140180    96.302953  130.395945   119.215280  ...           68.868714
# 5  145.790225   104.368733  147.140180    96.302953  ...           51.930169
# 6  137.984515   106.495640  145.790225   104.368733  ...           48.272617
# 7   62.204385   103.276103  137.984515   106.495640  ...           38.220056
# 8  118.025195    51.489237   62.204385   103.276103  ...           33.434839
# 9  146.479725    90.335197  118.025195    51.489237  ...           30.411710
#
#    pm1_rolling_mean_3  pm1_rolling_mean_7  pm1_rolling_std_7  pm2_5_ewma_3  \
# 0           68.605241           89.143408          45.201132     64.712948
# 1           60.995296           83.585000          39.339627     98.749082
# 2           74.787828           79.442713          36.021756    108.982181
# 3           91.618233           76.393456          35.060222    102.642567
# 4           83.424274           80.172253          33.652125    103.505650
# 5           80.318550           73.832442          26.591171    105.000645
# 6           82.289595           78.297741          24.780298    104.138374
# 7           70.142732           80.831178          18.760947     77.813805
# 8           66.470680           76.179035          15.486934     84.074501
# 9           67.210293           75.050226          14.309489     95.844286
#
#    pm2_5_ewma_7  pm10_ewma_3  pm10_ewma_7  pm1_ewma_3  pm1_ewma_7
# 0    102.274502    86.128249   141.872195   52.654414   80.576450
# 1    109.902181   134.368249   152.056209   78.885819   86.711644
# 2    112.230456   150.630087   155.765138   85.885688   88.255122
# 3    108.248580   140.513016   149.422840   81.368803   85.404321
# 4    107.278618   143.826598   148.852175   80.952075   84.187077
# 5    107.082874   144.808412   148.086687   82.260230   84.032404
# 6    106.131181   141.396463   145.561144   82.512641   83.715566
# 7     92.470695   101.800424   124.721954   63.303701   73.810365
# 8     91.936820   109.912810   123.047765   67.927964   73.495830
# 9     95.856133   128.196267   128.905755   76.455928   76.367846
#
# [10 rows x 34 columns]
# Features: 29

# %%
print("Missing values:")
print(
    combined_model_df[
        feature_columns + ["target_pm2_5"]
    ]
    .isna()
    .sum()
    .sum()
)

print("\nFinal shape:")
print(combined_model_df.shape)
# Out:
# Missing values:
# 0
#
# Final shape:
# (1879, 34)

# %% [markdown]
# Datasets into dictionaries

# %%
feature_datasets = {
    "Lag 7": df_model,
    "Rolling": rolling_model_df,
    "EWMA": ewma_model_df,
    "Change": change_model_df,
    "Combined": combined_model_df,
}

# %% [markdown]
# determine features

# %%
feature_columns_map = {}

for name, data in feature_datasets.items():

    features = [
        col
        for col in data.columns
        if col not in [
            "date",
            "pm2_5",
            "pm10",
            "pm1",
            "target_pm2_5",
        ]
    ]

    feature_columns_map[name] = features

    print(
        f"{name}: {len(features)} features"
    )
# Out:
# Lag 7: 21 features
# Rolling: 24 features
# EWMA: 6 features
# Change: 18 features
# Combined: 29 features

# %% [markdown]
# Chronological 80/20 split

# %%
splits = {}

for name, data in feature_datasets.items():

    split_index = int(len(data) * 0.8)

    train_df = data.iloc[:split_index].copy()
    val_df = data.iloc[split_index:].copy()
    features = feature_columns_map[name]
    X_train = train_df[features]
    y_train = train_df["target_pm2_5"]

    X_val = val_df[features]
    y_val = val_df["target_pm2_5"]

    splits[name] = {
        "X_train": X_train,
        "y_train": y_train,
        "X_val": X_val,
        "y_val": y_val,
    }

    print(
        f"{name}: "
        f"Train={len(train_df)}, "
        f"Validation={len(val_df)}"
    )
# Out:
# Lag 7: Train=1503, Validation=376
# Rolling: Train=1503, Validation=376
# EWMA: Train=1508, Validation=377
# Change: Train=1503, Validation=376
# Combined: Train=1503, Validation=376

# %% [markdown]
# Defining models

# %%
models = {
    "Linear Regression": LinearRegression(),

    "Ridge": Ridge(alpha=1.0),

    "Random Forest 100": RandomForestRegressor(
        n_estimators=100,
        random_state=42,
        n_jobs=-1,
    ),

    "Random Forest 300": RandomForestRegressor(
        n_estimators=300,
        random_state=42,
        n_jobs=-1,
    ),

    "Random Forest 500": RandomForestRegressor(
        n_estimators=500,
        random_state=42,
        n_jobs=-1,
    ),

    "Gradient Boosting 100": GradientBoostingRegressor(
        n_estimators=100,
        learning_rate=0.05,
        max_depth=3,
        random_state=42,
    ),

    "Gradient Boosting 200": GradientBoostingRegressor(
        n_estimators=200,
        learning_rate=0.05,
        max_depth=3,
        random_state=42,
    ),

    "Gradient Boosting 300": GradientBoostingRegressor(
        n_estimators=300,
        learning_rate=0.05,
        max_depth=3,
        random_state=42,
    ),

    "Extra Trees 100": ExtraTreesRegressor(
        n_estimators=100,
        random_state=42,
        n_jobs=-1,
    ),

    "Extra Trees 300": ExtraTreesRegressor(
        n_estimators=300,
        random_state=42,
        n_jobs=-1,
    ),

    "Extra Trees 500": ExtraTreesRegressor(
        n_estimators=500,
        random_state=42,
        n_jobs=-1,
    ),
}

# %% [markdown]
# Train models

# %%
results = []

trained_models = {}

for feature_name, split in splits.items():

    X_train = split["X_train"]
    y_train = split["y_train"]

    X_val = split["X_val"]
    y_val = split["y_val"]

    trained_models[feature_name] = {}

    print("\n" + "=" * 70)
    print(f"FEATURE SET: {feature_name}")
    print("=" * 70)

    for model_name, model in models.items():

        print(f"Training: {model_name}")

        model.fit(
            X_train,
            y_train,
        )

        predictions = model.predict(
            X_val
        )

        mae = mean_absolute_error(
            y_val,
            predictions,
        )

        rmse = np.sqrt(
            mean_squared_error(
                y_val,
                predictions,
            )
        )

        r2 = r2_score(
            y_val,
            predictions,
        )

        results.append({
            "Feature Set": feature_name,
            "Model": model_name,
            "Features": len(
                feature_columns_map[feature_name]
            ),
            "MAE": mae,
            "RMSE": rmse,
            "R2": r2,
        })

        trained_models[
            feature_name
        ][model_name] = model
# Out:
# ======================================================================
# FEATURE SET: Lag 7
# ======================================================================
# Training: Linear Regression
# Training: Ridge
# Training: Random Forest 100
# Training: Random Forest 300
# Training: Random Forest 500
# Training: Gradient Boosting 100
# Training: Gradient Boosting 200
# Training: Gradient Boosting 300
# Training: Extra Trees 100
# Training: Extra Trees 300
# Training: Extra Trees 500
#
# ======================================================================
# FEATURE SET: Rolling
# ======================================================================
# Training: Linear Regression
# Training: Ridge
# Training: Random Forest 100
# Training: Random Forest 300
# Training: Random Forest 500
# Training: Gradient Boosting 100
# Training: Gradient Boosting 200
# Training: Gradient Boosting 300
# Training: Extra Trees 100
# Training: Extra Trees 300
# Training: Extra Trees 500
#
# ======================================================================
# FEATURE SET: EWMA
# ======================================================================
# Training: Linear Regression
# Training: Ridge
# Training: Random Forest 100
# Training: Random Forest 300
# Training: Random Forest 500
# Training: Gradient Boosting 100
# Training: Gradient Boosting 200
# Training: Gradient Boosting 300
# Training: Extra Trees 100
# Training: Extra Trees 300
# Training: Extra Trees 500
#
# ======================================================================
# FEATURE SET: Change
# ======================================================================
# Training: Linear Regression
# Training: Ridge
# Training: Random Forest 100
# Training: Random Forest 300
# Training: Random Forest 500
# Training: Gradient Boosting 100
# Training: Gradient Boosting 200
# Training: Gradient Boosting 300
# Training: Extra Trees 100
# Training: Extra Trees 300
# Training: Extra Trees 500
#
# ======================================================================
# FEATURE SET: Combined
# ======================================================================
# Training: Linear Regression
# Training: Ridge
# Training: Random Forest 100
# Training: Random Forest 300
# Training: Random Forest 500
# Training: Gradient Boosting 100
# Training: Gradient Boosting 200
# Training: Gradient Boosting 300
# Training: Extra Trees 100
# Training: Extra Trees 300
# Training: Extra Trees 500

# %% [markdown]
# Create results table

# %%
results_df = pd.DataFrame(results)

results_df = (
    results_df
    .sort_values("RMSE")
    .reset_index(drop=True)
)

display(results_df)
# Out:
#    Feature Set                  Model  Features        MAE       RMSE  \
# 0         EWMA                  Ridge         6  10.718300  14.449193
# 1         EWMA      Linear Regression         6  10.719414  14.451705
# 2        Lag 7                  Ridge        21  10.819977  14.526336
# 3        Lag 7      Linear Regression        21  10.820300  14.526694
# 4     Combined                  Ridge        29  10.962481  15.235506
# 5     Combined      Linear Regression        29  10.976239  15.245860
# 6       Change  Gradient Boosting 300        18  13.058662  16.641008
# 7        Lag 7  Gradient Boosting 100        21  13.118899  17.540898
# 8        Lag 7  Gradient Boosting 200        21  13.063153  17.681460
# 9       Change      Random Forest 300        18  14.188621  17.690400
# 10      Change        Extra Trees 500        18  14.563158  17.822005
# 11      Change  Gradient Boosting 200        18  14.195799  17.828589
# 12      Change      Random Forest 500        18  14.284109  17.843452
# 13       Lag 7  Gradient Boosting 300        21  13.316706  17.898255
# 14      Change      Random Forest 100        18  14.245598  18.041308
# 15      Change        Extra Trees 300        18  14.721868  18.054661
# 16    Combined  Gradient Boosting 100        29  13.621921  18.122118
# 17      Change        Extra Trees 100        18  14.704719  18.134221
# 18     Rolling  Gradient Boosting 200        24  13.254745  18.220539
# 19     Rolling  Gradient Boosting 100        24  13.622606  18.347549
# 20        EWMA  Gradient Boosting 100         6  14.825455  18.665422
# 21     Rolling  Gradient Boosting 300        24  13.621355  18.716069
# 22        EWMA  Gradient Boosting 200         6  14.867606  18.808477
# 23    Combined  Gradient Boosting 200        29  15.763261  19.825926
# 24     Rolling                  Ridge        24  13.526577  19.899492
# 25     Rolling      Linear Regression        24  13.549336  19.948221
# 26    Combined  Gradient Boosting 300        29  15.863247  20.054283
# 27        EWMA  Gradient Boosting 300         6  16.355079  20.499424
# 28        EWMA        Extra Trees 100         6  16.412527  20.864131
# 29       Lag 7        Extra Trees 300        21  16.810089  20.977815
# 30        EWMA        Extra Trees 500         6  16.769336  21.131506
# 31       Lag 7        Extra Trees 500        21  17.100782  21.347308
# 32        EWMA        Extra Trees 300         6  16.906835  21.359024
# 33       Lag 7        Extra Trees 100        21  17.438928  21.803320
# 34      Change  Gradient Boosting 100        18  18.127815  22.055848
# 35    Combined      Random Forest 100        29  18.811247  23.831237
# 36    Combined        Extra Trees 100        29  19.232897  23.875775
# 37     Rolling        Extra Trees 100        24  19.259534  24.222193
# 38     Rolling      Random Forest 100        24  18.907647  24.245530
# 39    Combined        Extra Trees 300        29  19.547471  24.383361
# 40    Combined        Extra Trees 500        29  19.877845  24.735660
# 41       Lag 7      Random Forest 100        21  19.927385  24.758239
# 42     Rolling      Random Forest 300        24  19.664438  25.014758
# 43     Rolling      Random Forest 500        24  19.986045  25.452444
# 44     Rolling        Extra Trees 300        24  20.340925  25.647642
# 45     Rolling        Extra Trees 500        24  20.767593  26.159674
# 46    Combined      Random Forest 500        29  21.143205  26.831269
# 47        EWMA      Random Forest 500         6  21.283265  26.986643
# 48        EWMA      Random Forest 300         6  21.552030  27.203514
# 49    Combined      Random Forest 300        29  21.522919  27.563825
# 50       Lag 7      Random Forest 300        21  21.730089  27.694207
# 51       Lag 7      Random Forest 500        21  21.954285  28.100839
# 52        EWMA      Random Forest 100         6  22.299069  28.840754
# 53      Change      Linear Regression        18  41.736247  48.903115
# 54      Change                  Ridge        18  41.935438  49.125321
#
#           R2
# 0   0.787114
# 1   0.787040
# 2   0.785158
# 3   0.785148
# 4   0.763669
# 5   0.763348
# 6   0.718054
# 7   0.686736
# 8   0.681696
# 9   0.681374
# 10  0.676615
# 11  0.676376
# 12  0.675836
# 13  0.673842
# 14  0.668608
# 15  0.668117
# 16  0.665632
# 17  0.665186
# 18  0.661991
# 19  0.657262
# 20  0.644749
# 21  0.643355
# 22  0.639283
# 23  0.599803
# 24  0.596828
# 25  0.594851
# 26  0.590531
# 27  0.571508
# 28  0.556126
# 29  0.551950
# 30  0.544676
# 31  0.536027
# 32  0.534819
# 33  0.515993
# 34  0.504716
# 35  0.421771
# 36  0.419608
# 37  0.402644
# 38  0.401492
# 39  0.394668
# 40  0.377050
# 41  0.375912
# 42  0.362913
# 43  0.340423
# 44  0.330268
# 45  0.303259
# 46  0.267026
# 47  0.257396
# 48  0.245413
# 49  0.226455
# 50  0.219120
# 51  0.196020
# 52  0.151850
# 53 -1.434891
# 54 -1.457068

# %% [markdown]
# Rounding errors

# %%
results_display = results_df.copy()

results_display["MAE"] = (
    results_display["MAE"].round(3)
)

results_display["RMSE"] = (
    results_display["RMSE"].round(3)
)

results_display["R2"] = (
    results_display["R2"].round(3)
)

display(results_display)
# Out:
#    Feature Set                  Model  Features     MAE    RMSE     R2
# 0         EWMA                  Ridge         6  10.718  14.449  0.787
# 1         EWMA      Linear Regression         6  10.719  14.452  0.787
# 2        Lag 7                  Ridge        21  10.820  14.526  0.785
# 3        Lag 7      Linear Regression        21  10.820  14.527  0.785
# 4     Combined                  Ridge        29  10.962  15.236  0.764
# 5     Combined      Linear Regression        29  10.976  15.246  0.763
# 6       Change  Gradient Boosting 300        18  13.059  16.641  0.718
# 7        Lag 7  Gradient Boosting 100        21  13.119  17.541  0.687
# 8        Lag 7  Gradient Boosting 200        21  13.063  17.681  0.682
# 9       Change      Random Forest 300        18  14.189  17.690  0.681
# 10      Change        Extra Trees 500        18  14.563  17.822  0.677
# 11      Change  Gradient Boosting 200        18  14.196  17.829  0.676
# 12      Change      Random Forest 500        18  14.284  17.843  0.676
# 13       Lag 7  Gradient Boosting 300        21  13.317  17.898  0.674
# 14      Change      Random Forest 100        18  14.246  18.041  0.669
# 15      Change        Extra Trees 300        18  14.722  18.055  0.668
# 16    Combined  Gradient Boosting 100        29  13.622  18.122  0.666
# 17      Change        Extra Trees 100        18  14.705  18.134  0.665
# 18     Rolling  Gradient Boosting 200        24  13.255  18.221  0.662
# 19     Rolling  Gradient Boosting 100        24  13.623  18.348  0.657
# 20        EWMA  Gradient Boosting 100         6  14.825  18.665  0.645
# 21     Rolling  Gradient Boosting 300        24  13.621  18.716  0.643
# 22        EWMA  Gradient Boosting 200         6  14.868  18.808  0.639
# 23    Combined  Gradient Boosting 200        29  15.763  19.826  0.600
# 24     Rolling                  Ridge        24  13.527  19.899  0.597
# 25     Rolling      Linear Regression        24  13.549  19.948  0.595
# 26    Combined  Gradient Boosting 300        29  15.863  20.054  0.591
# 27        EWMA  Gradient Boosting 300         6  16.355  20.499  0.572
# 28        EWMA        Extra Trees 100         6  16.413  20.864  0.556
# 29       Lag 7        Extra Trees 300        21  16.810  20.978  0.552
# 30        EWMA        Extra Trees 500         6  16.769  21.132  0.545
# 31       Lag 7        Extra Trees 500        21  17.101  21.347  0.536
# 32        EWMA        Extra Trees 300         6  16.907  21.359  0.535
# 33       Lag 7        Extra Trees 100        21  17.439  21.803  0.516
# 34      Change  Gradient Boosting 100        18  18.128  22.056  0.505
# 35    Combined      Random Forest 100        29  18.811  23.831  0.422
# 36    Combined        Extra Trees 100        29  19.233  23.876  0.420
# 37     Rolling        Extra Trees 100        24  19.260  24.222  0.403
# 38     Rolling      Random Forest 100        24  18.908  24.246  0.401
# 39    Combined        Extra Trees 300        29  19.547  24.383  0.395
# 40    Combined        Extra Trees 500        29  19.878  24.736  0.377
# 41       Lag 7      Random Forest 100        21  19.927  24.758  0.376
# 42     Rolling      Random Forest 300        24  19.664  25.015  0.363
# 43     Rolling      Random Forest 500        24  19.986  25.452  0.340
# 44     Rolling        Extra Trees 300        24  20.341  25.648  0.330
# 45     Rolling        Extra Trees 500        24  20.768  26.160  0.303
# 46    Combined      Random Forest 500        29  21.143  26.831  0.267
# 47        EWMA      Random Forest 500         6  21.283  26.987  0.257
# 48        EWMA      Random Forest 300         6  21.552  27.204  0.245
# 49    Combined      Random Forest 300        29  21.523  27.564  0.226
# 50       Lag 7      Random Forest 300        21  21.730  27.694  0.219
# 51       Lag 7      Random Forest 500        21  21.954  28.101  0.196
# 52        EWMA      Random Forest 100         6  22.299  28.841  0.152
# 53      Change      Linear Regression        18  41.736  48.903 -1.435
# 54      Change                  Ridge        18  41.935  49.125 -1.457

# %% [markdown]
# Best for each feature set

# %%
best_by_feature = (
    results_df
    .sort_values("RMSE")
    .groupby("Feature Set")
    .first()
    .reset_index()
)

display(
    best_by_feature[
        [
            "Feature Set",
            "Model",
            "Features",
            "MAE",
            "RMSE",
            "R2",
        ]
    ]
)
# Out:
#   Feature Set                  Model  Features        MAE       RMSE        R2
# 0      Change  Gradient Boosting 300        18  13.058662  16.641008  0.718054
# 1    Combined                  Ridge        29  10.962481  15.235506  0.763669
# 2        EWMA                  Ridge         6  10.718300  14.449193  0.787114
# 3       Lag 7                  Ridge        21  10.819977  14.526336  0.785158
# 4     Rolling  Gradient Boosting 200        24  13.254745  18.220539  0.661991

# %% [markdown]
# Overall winner

# %%
best_result = (
    results_df
    .sort_values("RMSE")
    .iloc[0]
)

print("BEST MODEL for data with pm1")
print("-" * 40)

print("Feature Set:", best_result["Feature Set"])
print("Model:", best_result["Model"])
print("Features:", best_result["Features"])
print("MAE:", round(best_result["MAE"], 3))
print("RMSE:", round(best_result["RMSE"], 3))
print("R²:", round(best_result["R2"], 3))
# Out:
# BEST MODEL for data with pm1
# ----------------------------------------
# Feature Set: EWMA
# Model: Ridge
# Features: 6
# MAE: 10.718
# RMSE: 14.449
# R²: 0.787

# %% [markdown]
# ## For our current dataset and chronological validation split, adding PM1 did not improve PM2.5 forecasting performance.
